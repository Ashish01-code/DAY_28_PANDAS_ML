# %%
import pandas as pd
df=pd.read_csv(r"E:\TEST\AUTO_MARKS.csv")
print(df.shape)
print(df.head())
print(df.tail())
print(df.columns)
# Out:
# (48, 7)
#    Student_Name Department Year Section  Marks Result Grade
# 0  Aarav Sharma        CSE  3rd       C     90   Pass     A
# 1    Diya Patel         ME  1st       B     51   Pass     D
# 2   Rohan Verma        EEE  3rd       C     57   Pass     C
# 3  Ananya Singh         ME  2nd       C     56   Pass     C
# 4   Kunal Mehta         CE  3rd       A     92   Pass     A
#      Student_Name Department Year Section  Marks Result Grade
# 43     Komal Jain        EEE  4th       A     60   Pass     C
# 44     Sahil Khan         CE  4th       C     54   Pass     D
# 45    Nandini Roy        ECE  3rd       B     32   Fail     F
# 46  Rajesh Pillai        EEE  3rd       A     30   Fail     F
# 47  Bhavya Mittal        ECE  2nd       C     36   Fail     F
# Index(['Student_Name', 'Department', 'Year', 'Section', 'Marks', 'Result',
#        'Grade'],
#       dtype='object')

# %%
import pandas as pd
df=pd.read_csv(r"E:\TEST\AUTO_MARKS.csv")
print(df[["Student_Name","Grade"]])
# Out:
#           Student_Name Grade
# 0         Aarav Sharma     A
# 1           Diya Patel     D
# 2          Rohan Verma     C
# 3         Ananya Singh     C
# 4          Kunal Mehta     A
# 5           Priya Iyer     B
# 6           Aditya Rao     B
# 7          Sneha Gupta     D
# 8          Vikram Nair     D
# 9          Neha Kapoor     A
# 10      Arjun Malhotra     B
# 11         Pooja Desai     C
# 12    Rahul Chatterjee     F
# 13     Ishita Banerjee     A
# 14      Siddharth Jain     B
# 15      Nisha Aggarwal     C
# 16        Manish Yadav     F
# 17         Kavya Reddy     B
# 18        Suresh Kumar     B
# 19          Mehul Shah     C
# 20         Tanvi Joshi     C
# 21       Amit Kulkarni     B
# 22        Shreya Ghosh     B
# 23        Varun Saxena     A
# 24        Ritika Arora     F
# 25        Akash Mishra     F
# 26        Swati Pandey     B
# 27        Nitin Bansal     D
# 28  Aishwarya Kulkarni     B
# 29       Harsh Vardhan     C
# 30         Simran Kaur     A
# ...

# %%
import pandas as pd
df=pd.read_csv(r"E:\TEST\AUTO_MARKS.csv")
print(df.shape)
print(df.columns)
print(df.head())
print(df.tail())
# Out:
# (48, 7)
# Index(['Student_Name', 'Department', 'Year', 'Section', 'Marks', 'Result',
#        'Grade'],
#       dtype='object')
#    Student_Name Department Year Section  Marks Result Grade
# 0  Aarav Sharma        CSE  3rd       C     90   Pass     A
# 1    Diya Patel         ME  1st       B     51   Pass     D
# 2   Rohan Verma        EEE  3rd       C     57   Pass     C
# 3  Ananya Singh         ME  2nd       C     56   Pass     C
# 4   Kunal Mehta         CE  3rd       A     92   Pass     A
#      Student_Name Department Year Section  Marks Result Grade
# 43     Komal Jain        EEE  4th       A     60   Pass     C
# 44     Sahil Khan         CE  4th       C     54   Pass     D
# 45    Nandini Roy        ECE  3rd       B     32   Fail     F
# 46  Rajesh Pillai        EEE  3rd       A     30   Fail     F
# 47  Bhavya Mittal        ECE  2nd       C     36   Fail     F

# %%
print(df[["Student_Name","Grade"]])
# Out:
#           Student_Name Grade
# 0         Aarav Sharma     A
# 1           Diya Patel     D
# 2          Rohan Verma     C
# 3         Ananya Singh     C
# 4          Kunal Mehta     A
# 5           Priya Iyer     B
# 6           Aditya Rao     B
# 7          Sneha Gupta     D
# 8          Vikram Nair     D
# 9          Neha Kapoor     A
# 10      Arjun Malhotra     B
# 11         Pooja Desai     C
# 12    Rahul Chatterjee     F
# 13     Ishita Banerjee     A
# 14      Siddharth Jain     B
# 15      Nisha Aggarwal     C
# 16        Manish Yadav     F
# 17         Kavya Reddy     B
# 18        Suresh Kumar     B
# 19          Mehul Shah     C
# 20         Tanvi Joshi     C
# 21       Amit Kulkarni     B
# 22        Shreya Ghosh     B
# 23        Varun Saxena     A
# 24        Ritika Arora     F
# 25        Akash Mishra     F
# 26        Swati Pandey     B
# 27        Nitin Bansal     D
# 28  Aishwarya Kulkarni     B
# 29       Harsh Vardhan     C
# 30         Simran Kaur     A
# ...

# %%
print(df.iloc[0:5])
# Out:
#    Student_Name Department Year Section  Marks Result Grade
# 0  Aarav Sharma        CSE  3rd       C     90   Pass     A
# 1    Diya Patel         ME  1st       B     51   Pass     D
# 2   Rohan Verma        EEE  3rd       C     57   Pass     C
# 3  Ananya Singh         ME  2nd       C     56   Pass     C
# 4   Kunal Mehta         CE  3rd       A     92   Pass     A
# Student_Name    Aarav Sharma
# Department               CSE
# Year                     3rd
# Section                    C
# Marks                     90
# Result                  Pass
# Grade                      A
# Name: 0, dtype: object

# %%
print(df.loc[0])
# Out:
# Student_Name    Aarav Sharma
# Department               CSE
# Year                     3rd
# Section                    C
# Marks                     90
# Result                  Pass
# Grade                      A
# Name: 0, dtype: object

# %%
filtered=df[df["Marks"]>50]
print(filtered)
# Out:
#           Student_Name Department Year Section  Marks Result Grade
# 0         Aarav Sharma        CSE  3rd       C     90   Pass     A
# 1           Diya Patel         ME  1st       B     51   Pass     D
# 2          Rohan Verma        EEE  3rd       C     57   Pass     C
# 3         Ananya Singh         ME  2nd       C     56   Pass     C
# 4          Kunal Mehta         CE  3rd       A     92   Pass     A
# 5           Priya Iyer        ECE  1st       C     76   Pass     B
# 6           Aditya Rao        CSE  4th       A     74   Pass     B
# 9          Neha Kapoor         CE  2nd       A     86   Pass     A
# 10      Arjun Malhotra        EEE  3rd       B     76   Pass     B
# 11         Pooja Desai      AI&DS  1st       B     60   Pass     C
# 13     Ishita Banerjee         ME  1st       B     97   Pass     A
# 14      Siddharth Jain         ME  1st       B     75   Pass     B
# 15      Nisha Aggarwal         CE  1st       A     64   Pass     C
# ...
